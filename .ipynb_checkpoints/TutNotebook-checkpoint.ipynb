# %% [markdown]
# ## Introduction
#
# - Tutorial on Mining of supporting and objecting units .
# - Presenter: Harsh Shah, Meher Vivek, Rene Sherf
# - Task: Find the stance of evidence towards the claim

# %% [markdown]
# - Inspired by [Bar-Haim et al.  2017](https://www.aclweb.org/anthology/E17-1024)
# .
#     - Paper: Stance Classification of Context-Dependent Claims
#     - Input: Topics, Claims
#     - Output: Stance of claim towards the topic

# %%
from stanceDetectionModel import StanceDetectionModel

# %%
model = StanceDetectionModel()

# %%
# Import dataset
import pandas as pd
data = pd.read_csv('Dataset/claim_stance_dataset_v1.csv') 
claim_corrected_data = data.iloc[:,7]

# %% [markdown]
# ## Preprocessing of Data
# -                Remove Stopwords
# -                Stemming
# -                Lemmatization

# %%
claim_corrected_data = data.iloc[:,7]
claim_corrected_data_cleaned = model.remove_stop_words(claim_corrected_data)
claim_corrected_data_stemmed = model.get_stemmed_text(claim_corrected_data_cleaned) 
claim_lemmatized_reviews = model.get_lemmatized_text(claim_corrected_data_stemmed)

# %%
claim_lemmatized_reviews
# Out:
# ['exposur violent video game caus least temporari increas aggress exposur correl aggress real world',
#  'video game violenc relat seriou aggress behavior real life',
#  'violent video game may actual prosoci effect context',
#  'exposur violent video game caus short term long term aggress player decreas empathi prosoci behavior',
#  'violent video game increas violent tendenc among youth',
#  'No conclus link found video game usag violent activ',
#  'violent video game significantli associ with: increas aggress behavior, thoughts, affect; increas physiolog arousal; decreas pro-soci (helping) behavior',
#  'video game publish uneth train child use weapon and, importantly, harden emot act murder',
#  'violent video game may increas mild form aggress behavior child young adult',
#  'exposur violent video game result increas physiolog arousal, aggression-rel thought feel well decreas prosoci behavior',
#  'No long-term relationship found play violent video game youth violenc bulli',
#  'aggress child tend select violent video games, invers',
#  'No evid found violent game psycholog harm minor',
#  'adolesc play video game at-risk violent behavior',
#  "video game play part adolesc boy' normal social set",
#  'biolog theori aggress violenc specif exclud video game medium effect',
#  'reinforc sexist stereotyp claim effect violent video game',
#  'A correl found child play violent video game suffer psycholog effect',
#  "violent video game increas children' aggress",
#  'medium influenc weak distant much influenc aggress',
#  'violent video game promot violent behavior, attitud belief desensit individu aggress',
#  'excess exposur violent video game violent medium link aggress behaviour',
#  'neurolog link found play violent video game aggress behaviour child teenag',
#  'there direct link violent video game influenc child',
#  "video game develop individual' intellig",
#  'violent game help student deal stress aggress',
#  'violent game affect student posit neg',
#  'mani skill learn game experience, build practic intellectu skill',
#  'medium cannot caus violenc human abil recogn wrong, right',
#  'video game mani healthi posit aspect',
#  'video game safe outlet aggress frustrat',
#  "violent video game influenc children' view violenc",
#  'variou game accus caus addict even violent behavior',
#  'exposur graphic violenc lead desensit commit act violenc person',
#  'violenc game harden child uneth act',
#  'child may imit aggress behavior wit medium',
#  'child automat imit aggression, rather consid context aggress',
#  'societ medium consumpt violent crime rate well associ',
#  'medium violenc may increas aggress',
#  'evid harm effect video game violenc inconclus',
#  'violent video game - especi first-person shooter game - encourag real-lif act violenc teenag',
#  'video game allow child act crime',
#  'violenc video game causal link aggress tendenc',
#  'correl violent gameplay com childhood problem found',
#  'child play violent game problem',
#  'mani creative, social emot benefit video game play document - even game violent content',
#  'not depict violenc bad wit',
#  'there connect exposur medium violenc real life violenc',
#  'heavi exposur medium violenc lead aggress behavior',
#  'exposur alon medium violenc caus child commit crime',
#  'convinc evid prove medium violenc caus violent crime type real life violenc',
#  'exposur violent video games[ref] relat increas aggress child',
#  'numer research propos potenti posit effect video game',
#  'comput game caus violenc',
#  'A correl violent content convey medium (includ videogames) violent aggress behavior shown',
#  'some seriou psycholog problem attribut desensit violenc video game',
#  'video game protect speech first amend',
#  'there connect video game violenc',
#  'content-bas regul presumpt invalid',
#  'No evid link video game youth violenc',
#  'there compel link violent video game effect child',
#  'content-bas restrict game unconstitut',
#  'parents, govern bureaucrats, right decid appropri child',
#  'state “right regul sale video game [that violent] order protect minor',
#  'parent make decision” video game purchas children, constitut “too violent',
#  'state right decid video game violent [minor',
#  'violent game caus youth violenc',
#  'A high degre relationship violent game youth violenc indic',
#  'video game violenc lead youth violenc',
#  'video game content form freedom express',
#  'social util express imagin form entertainment, even contain violenc',
#  'there tangibl benefit violenc game',
#  'the polici controversi within outsid china manner polici implemented, concern neg social consequ',
#  "the polici possibl caus behind china' gender imbal",
#  'the polici prove remark effect',
#  "the polici consid great success help implement china' current econom growth",
#  'the reduct fertil rate thu popul growth reduc sever problem come overpopul',
#  'focu china popul control help provid better health servic woman',
#  'the individu save rate increas sinc one-child polici introduc',
#  'le intrus options, includ emphas delay space births, could achiev result extend period time',
#  't]he polici probabl partial respons reduct total fertil rate',
#  'china could expect continu reduct fertil rate continu econom development, kept previou polici',
#  "the one-child polici challeng principl practic violat human right determin size one' famili",
#  'the polici leav older gener increas chanc depend retir fund chariti order receiv support',
#  'if, reason, singl child unabl care older adult relatives, oldest gener would face lack resourc necess',
#  'some parent may over-indulg child',
#  'the one child polici creat social problem person disord young peopl',
#  'the one-child limit extreme. It violat nature’ law',
#  'the social pressur exert one-child polici affect rate parent abandon undesir child',
#  "china' famili plan program contribut infanticid",
#  'singl child would left provid support two parent four grandpar',
#  'coerciv steril enforc one child polici occur china',
#  'As result one child policy, china success achiev goal stabl much-reduc fertil rate',
#  'rapid popul growth seen obstacl develop',
#  'popul control necessari econom growth improv live standard',
#  'coerciv measur use achiev desir result one-child polici',
#  'rapid fertil reduct associ one-child polici potenti neg result',
#  'decreas human popul would prevent signific amount man-mad human suffer',
#  "A continu rapid popul growth occur would hinder china' develop nation",
#  'polici creat abus woman china',
#  'implement polici involv forc abort forc steril',
#  "china' gender imbal increas one child polici",
#  "china' birth control polici contribut forc abort",
#  "china' birth control polici thought signific contribut gender imbal mainland china",
#  'one-child polici effect enough justifi cost',
#  'dramat decreas chine fertil start program began 1979 unrel factor',
#  "popul control involv measur improv people' live",
#  'A larg increas popul bring certain poverti citizenri',
#  'excess popul growth may reduc output per worker',
#  'A larger popul mean product',
#  'overpopul blame varieti issues, includ increas poverti',
#  'reduct popul key econom growth',
#  'economist doubt correl popul reduct econom growth exist',
#  'poverti famin caus bad govern bad econom policies, overpopul',
#  'higher popul densiti lead special technolog innovation, turn lead higher standard live',
#  'human be ultim resourc',
#  'correl popul densiti poverti starvat',
#  'there number problem associ overpopul',
#  'the success polici questioned, reduct fertil also attribut modern china',
#  'the polici controversi within outsid china',
#  'parent basic human right determin freeli respons number space child',
#  'parent basic right decid freeli respons number space child',
#  'parent exclus right determin freeli respons number space child',
#  "govern respons meet individuals' reproduct need",
#  'the human right woman includ right control decid freeli respons matter relat sexual',
#  'control reproduct basic need basic right woman',
#  'program take interest woman account unlik succeed',
#  "the policies' narrow focu lead coercion decreas qualiti care",
#  'four-two-on reconfigur famili structur distinct ramif chine societi',
#  'child spoil',
#  'child avers social skill',
#  'lack sibl blame number social ill',
#  'the one child polici specul underli caus forc abort',
#  'difficult child cooper convent famili environ',
#  'child higher achiev motiv',
#  'child mani sibl receiv fewer resourc',
#  'onli child like make outsid friend',
#  "rapid popul growth damag earth' resourc diminish human well-b",
#  'overpopul seen seriou threat qualiti human life',
#  'the use drug enhanc perform consid uneth intern sport organ',
#  'the use performance-enhanc drug littl differ use new materi construct suit sport equipment, similarli aid perform give competitor unfair advantag other',
#  'the use anabol steroid ban major sport bodi',
#  'drug test wildli inconsist and, instances, gone unenforc',
#  'there littl danger anabolica, athlet kept strictli monitor programm',
#  'the extrem danger side-effect performance-enhanc drug admit',
#  'often, dope carri without knowledg athletes, young ten year age',
#  'around 10,000 former athlet bear physic mental scar year drug abus',
#  'pursuit dope athlet turn modern day witch-hunt',
#  'mani sport organ ban use perform enhanc drug strict rule consequ peopl caught use',
#  'outright prevent dope impossibility, dope legalis',
#  'there harm long-term effect mani dope agent',
#  'with medic data support claim health problem caus performance-enhanc drugs, is, best, question',
#  'dope legal, competit athlet would compel use drugs, net effect would level play field widespread health consequ',
#  'dope could legal extent use drug whitelist medic counseling, medic safeti ensured, usag publish',
#  'athlet point alreadi danger environ sport like footbal martial art wonder doubl standard health concern brought aggress natur sport view accept ped',
#  'anybodi free put substanc choos bodi reason',
#  'substanc abus harm health may even deadli certain scenario',
#  'the use performance-enhanc substanc player illeg ethic "wrong',
#  'there wide rang health concern user anabol steroid',
#  'mani former athlet suffer health problem relat steroid consumpt',
#  'the extrem danger side-effect anabolica admit',
#  'former athlet bear physic mental scar year drug abus',
#  'health risk produc long-term use excess dose anabol steroid',
#  'frequent regular physic exercis boost immun system',
#  'physic exercis help prevent diseas affluenc',
#  'physic exercis improv mental health',
#  'physic exercis may help decreas effect childhood adult obes',
#  'physic exercis import maintain physic fit',
#  'physic exercis contribut posit maintain healthi weight',
#  'physic exercis strenghten immun system',
#  'frequent regular aerob exercis shown help prevent treat seriou life-threaten chronic condit',
#  'not everyon benefit equal exercis',
#  'moder exercis benefici effect human immun system',
#  'exercis alon potenti prevent method and/or treatment mild form depress',
#  'too much exercis harm',
#  'inappropri exercis harm good',
#  'introduc student activ like bowling, walking/hiking, frisbe earli age help student develop good activ habit carri adulthood',
#  'teach non-tradit sport student may provid necessari motiv student increas activity, help student learn differ cultur',
#  'child fail engag regular physic activ greater risk obes',
#  'peopl improv health via exercis',
#  'p.e. actual increas test score',
#  'youth get physic outlet need cognit develop physic health',
#  'excess weight reach epidem proport global',
#  'physic fit prevent treat mani chronic health condit',
#  'To stay healthi import engag physic activ',
#  'lack physic activ thought explain case obes',
#  'A sedentari lifestyl play signific role obes [ref',
#  'model ideal educ occur peopl go initi discov thing',
#  'physic inact increas high among mani group popul',
#  'peopl die result physic inact',
#  'inact one lead prevent caus death worldwid',
#  'school made fit child, rather way around',
#  'child learn best freedom coercion',
#  'mani child lead rel sedentari lifestyl',
#  'there mani health relat benefit physic activ',
#  'affirm action counter effect histori discrimin',
#  'affirm action intend promot equal opportun',
#  'affirm action intend ensur minor group within societi includ program',
#  'affirm action help compens past discrimination, persecut exploit rule class cultur',
#  'principl equal sometim requir state parti take affirm action order diminish elimin condit caus help perpetu discrimin prohibit coven',
#  'In countri law racial equality, affirm action render illeg treat race equal',
#  'affirm action law caus disproport high cost small compani reduc econom growth employ',
#  'imposs favor somebodi without discrimin other',
#  'affirm action devalu accomplish peopl chosen base social group belong rather qualif',
#  'affirm action devalu accomplish belong group intend help, therefor make affirm action counterproduct',
#  'affirm action "revers discrimin',
#  'affirm action undesir side-effect addit fail achiev goal',
#  'affirm action may increas racial tension benefit privileg peopl within minor group expens least fortun within major group',
#  'affirm action polici encourag non-pref group design member prefer group',
#  'affirm action polici tend benefit primarili fortun among prefer group',
#  'affirm action polici increas animos toward prefer group',
#  'affirm action hurt intend beneficiari',
#  'merit primari consider evalu',
#  "you can't legisl moral",
#  'attempt antidiscrimin critic revers discrimin',
#  'affirm action discrimin member domin major group',
#  "individual' civil right includ right free govern sponsor social discrimin",
#  'state must take measur seek elimin prejudic',
#  'histor racism continu reflect socio-econom inequ',
#  'racial stratif continu occur',
#  'polici adopt affirm action critic form refers discrimin',
#  'motiv affirm action polici redress effect past discrimin',
#  'affirm action polici demonstr overt prefer applic particular background better-qualifi (or equally-qualified) candid background',
#  'consider choos applic merit',
#  'affirm action perpetu racial divis',
#  'differenti treatment racial group intend amelior past discrimin',
#  "recognit right accord specif group may interfer state' need establish cohes ident",
#  'member minor requir specif provis right ensur marginalis within societi',
#  'affirm action polici may consid necessari minor group question social disadvantag',
#  'racial prejudic discrimin longer exist',
#  'affirm action racial division, racial reconcili',
#  'affirm action polici redress imbal promot equal',
#  'affirm action polici specif racial group guarante full equal enjoy human right fundament freedom',
#  'discrimin inher affirm action program',
#  'ident treatment may sometim act preserv inequ rather elimin',
#  'peopl treat similarli',
#  'job go “most qualifi',
#  'the select process base arbitrari irrelev criterion',
#  'race sex matter get job',
#  'final select post must made accord principl best person job',
#  'the overal idea affirmit action give child le fortun background chanc',
#  'the idea affirm action help disadvantag group get back normal start posit long period discrimin',
#  'equal achiev entail futur inequ',
#  'equal opportun ideal cannot realiz action govern',
#  'the impetu toward affirm action redress disadvantages[ref][ref][ref][ref][ref] associ overt histor discrimin',
#  'polici adopt affirm action criticis form revers discrimin',
#  'affirm action aim correct effect past present discrimin',
#  'one legal right demograph characterist posse consid favor point behalf',
#  'race-consci affirm action remain necessari address race-bas obstacl',
#  'affirm action often contest constitut ground',
#  'affirm action requir discrimin seek elimin',
#  'affirm action counter-product',
#  'affirm action lower bar',
#  'affirm action undesir side-effect',
#  'affirm action fail achiev goal',
#  'affirm action hinder reconcili',
#  'affirm action replac old wrong new wrong',
#  'affirm action undermin achiev minor',
#  'affirm action encourag group identifi disadvantaged, even',
#  'affirm action may increas racial tension',
#  'affirm action devalu accomplish peopl belong group suppos help',
#  'affirm action creat cult victim',
#  'affirm action polici reduc incent prefer non-pref perform best',
#  'affirm action polici engend animos toward prefer group',
#  'affirm action violat principl equal treatment much neg discrimin',
#  'one group favor expens anoth whenev quota invok',
#  'use quota displac individu would normal favor base individu achiev',
#  'qualif determin factor',
#  'type affirm action give prefer individu sole base race gender permit',
#  'social inequ today due "cultur deficits" individu peopl racial ethnic group',
#  'need pay "systemat attention" current inequ',
#  'affirm action program best neglig impact group intend assist',
#  'prefer polici reduc incent prefer non-pref perform best',
#  'direct intervent distribut asset opportun need resolv econom dispar',
#  'affirm action design improv well perceiv backward repres commun',
#  'the identif oppress class difficult carri',
#  'box commiss sanction bodi establish regul sport',
#  'fighter wear protect headgear, reduc number injuries, knockdowns, knockout',
#  'A refere monitor fight ensur competitor use legal blow',
#  'headgear permit profession bouts, boxer gener allow take much damag fight halt',
#  'refere may stop contest believ one particip cannot defend due injuri',
#  'knock person unconsci even caus concuss may caus perman brain damag',
#  'there clear divis forc requir knock person forc like kill person',
#  'amateur boxers, profession boxer toughman fighter die result ring train injuri',
#  'box obscen sanction civil societi',
#  'medic associ call ban box',
#  'box sport hurt athlet goal',
#  'box sport intent inflict seriou injuri oppon',
#  'protect headgear prevent brain damag',
#  'amateur boxer face high risk brain damag',
#  'refere stop bout boxer serious injur',
#  'the refere interven avoid unnecessari damag potenti injuri',
#  'the typic knock result sustain loss conscious',
#  'repeat blow head known gradual caus perman brain damag',
#  'In sever case box may caus stroke paralysi',
#  'mani physician advis sport involv knockout',
#  'fatal rare heavyweight match',
#  'rule chang made certain kind box death far rarer',
#  'box remain 8th deadli sport',
#  'sport relat combat skill part human cultur thousand year',
#  'contact sport higher risk transmiss blood-born diseas player',
#  'full-contact sport barbar',
#  'full contact sport tend caus injuri',
#  'box may caus DP',
#  'box brutal',
#  'powerpunch lot damag boxer',
#  'medic group call ban sport',
#  'diver must preval valu',
#  'differ recogn unit compon rather separ one',
#  'A multicultur societi never strong',
#  'mani multicultur societi fail',
#  'multicultur peril concept found polici',
#  'multicultur result polit corrupt',
#  'multicultur creat friction within societi',
#  'diver cultur express "rich asset individu societi',
#  'promot mainten cultur diver essenti requir sustain develop',
#  'diver bring progress social cohes',
#  'cultur diver necessari humankind biodivers natur',
#  'cultur diver common heritag human',
#  'cultur diver may vital long-term surviv human',
#  'cultur diver necessari humankind biodivers natur',
#  'It uneth conserv le develop societi',
#  'best interest individu human whole peopl adher specif model societi',
#  'multicultur becom polit euphemist way affirm persist unequ power relationship',
#  'multicultur tend emphas right ethnic minor expens major',
#  'the idea multicultur reach end use life',
#  'multicultur allow creat societi valu equal',
#  'cultur differ within societi valuabl preserv',
#  'ethnic nation group right maintain preserv cultur distinct integr',
#  "one need assimil abandon one' heritag order blend",
#  'assimil hurt minor cultur strip away distinct featur',
#  'separ citizen ethnic race provid immigr group "special privileges" harm group intend help',
#  'multiculturalist polici freer immigr unwork era suppli immigr third world countri seem limitless',
#  'there ration ground curtail cultur freedom',
#  'multination singl state necessarili compris right express exercis nation ident even minor',
#  'peopl right digniti diver cultur',
#  "distinct people' ident right preserv heritag acknowledg",
#  'multicultur classroom promot decision-mak critic think',
#  'multicultur tool instil student pride confid uniqu special background',
#  'multicultur educ provid rel fairer learn environ intern student',
#  'multicultur educ may caus abandon origin cultur',
#  'diver intrins valuabl domin cultur',
#  'A homogen commun ground consensu may unabl critic injustic exclusionari practic undermin',
#  'reform cultur patholog often come recognit differ',
#  'multicultur development journey individu enhanc knowledg skill differ cultur',
#  'multicultur educ public school would promot accept diver',
#  'citizen diver democrat societi abl maintain attach cultur commun',
#  'uniti without diver result cultur repress',
#  'strongest nation made differ racial element',
#  'multicultur help bring togeth immigr minor countri',
#  'offici multicultur limit freedom minor member',
#  'multicultur work better theori practic',
#  'multicultur perpetu conflict within group',
#  'multicultur hinder equiti equal societi',
#  'diver valuabl itself, preserv human histor heritag knowledg',
#  'diver make avail way solv problem respond catastroph',
#  'the greater public good warrant elimin cultur characterist promot conflict prevent harmoni',
#  'A commun separ cultur foster right mentality, rather respons mental',
#  'A commun separ cultur divis',
#  'A commun separ cultur work quick effect integr',
#  'multicultur obscur social cost associ larg scale immigr',
#  'multicultur divis',
#  'multicultur threaten social cohes',
#  'multicultur undermin nation uniti',
#  'form multicultur divid peopl',
#  'multicultur consid danger west',
#  'cultur civil equal valu',
#  'all cultur civil treat promot equal',
#  "peopl right maintain affili one' ethnic group",
#  'commun enrich differ accru',
#  'multicultur shift toler multipl cultur toler multipl valu systems, hostil liber',
#  'multicultur would lead accept barbar practic',
#  'homogen integr necessari societi',
#  'multicultur immigr lead adapt problem',
#  'immigr must alway lose cultur - price immigr',
#  'lack integr threaten societi',
#  'A liber democraci cannot multicultur',
#  'democraci rule law restor abolish multicultur',
#  'the emphasi group ident group right diminish individu liberti within minor',
#  'human be equal; cultur',
#  'state multicultur fail',
#  'uniti seen essenti featur nation nation-st',
#  'multicultur allow peopl truli express within societi',
#  'multicultur promot respect digniti live voic forgotten',
#  'multicultur tri restor sen whole postmodern era fragment human life thought',
#  "multicultur ultim erod host nations' distinct cultur",
#  'racial diver commun is, greater loss trust',
#  "recognit right accord specif group may interfer state' need establish cohes ident",
#  'member minor see specif need ambit acknowledg cater for, commit willingli accept legitimaci nation',
#  'polit function right precis protect minor oppress major',
#  'cultur appreci ethnic religi diver promot greater willing toler polit differ',
#  'gambl major intern commerci activ',
#  'cathol jewish tradit even set asid day gambl',
#  'religi author gener disapprov gambl',
#  'moral impedi gambl',
#  'legal jurisdict limit gambl',
#  'mani jurisdictions, local well national, either ban gambl heavili control licens',
#  'regul gener lead gambl tourism illeg gambl',
#  'legal gambl provid signific govern revenu',
#  'high-payoff low probability, hous bia quit easili miss',
#  'bet team sport becom import servic industri mani countri',
#  'mani peopl particip gambl form recreat even mean gain incom',
#  'gambling, like behavior involv variat brain chemistry, becom psycholog addict harm behavior',
#  'gambler persist gambl even repeat loss',
#  'social econom consequ casino gambl outweigh initi revenu may gener',
#  'gambl form anoth seen almost everi societi histori',
#  'most game play casino mathematically-determin odd ensur hous time advantag player',
#  'slot machin addict',
#  'given larg amount currenc handl within casino, patron staff may tempt cheat steal',
#  'one area controversi surround casino relationship crime rate',
#  'there posit relationship casino crime',
#  'In chariti gambl profit ventur go chariti group charities, rather municip privat casino',
#  'problem gambl shown caus dysfunct famili',
#  'As result gambling, driven extrem length cover debt',
#  'addict gambler spend energi follow addict',
#  'addict gambler cost compani loss product profit',
#  'gambler may suffer depress bankruptci',
#  'the social cost gambl societi vari',
#  'gambl provid job',
#  'gambl increas aggreg demand good servic economi',
#  'money gambl goe directli toward stimul economi',
#  'econom benefici state allow support gambl institut',
#  'patholog gambl common disord associ social cost',
#  'problem gambl lead advers consequ gambler, others, commun',
#  'patholog gambl addict similar chemic addict',
#  'problem gambler erron belief keep playing, eventu win',
#  'patholog gambl similar mani impuls control disord',
#  'As debt build peopl turn sourc money theft',
#  'compuls gambl often detriment person relationship',
#  'abus common home patholog gambl present',
#  'problem gambl often associ increas suicid ideat',
#  'problem gambl increas lifetim risk suicid',
#  'internet gambl grow problem bank credit card compani',
#  'regul onlin gambl better altern prohibit internet gambl',
#  'internet gambl legitim activ citizen right engag',
#  'internet gambl becom one popular lucr busi present internet',
#  'gambl diverse, vibrant innov industri',
#  'gambl popular leisur activ enjoy mani form million peopl',
#  'variou form onlin gambl legal regul mani countri',
#  'high-spe instant gratif internet game high level privaci offer may exacerb problem patholog gambl',
#  'electron fund transfer inher onlin gambl exploit crimin interest',
#  'the lotteri prove popular hail painless form taxat',
#  'there problem associ win lotteri jackpot',
#  'winner sometim feel anomi dramat chang lifestyl',
#  'lotteri facilit higher degre inequ societi',
#  'social system alloc resourc base chanc one corrupt',
#  'ani form gambl suscept fraud',
#  'gambl lead increas polit corruption, compuls gambl higher crime rate',
#  'gambl type regress tax individu',
#  "nearli western states' govern outlaw gambl",
#  'major state run type lotteri rais fund state oper',
#  'immigr high rate crimin',
#  'immigr thought compet employe alreadi countri',
#  'immigr threaten nation ident',
#  'freedom movement often recogn civil right',
#  'everyon right leav enter country, along movement within',
#  'everyon right leav country, includ own, return countri',
#  'freedom movement within countri basic human right',
#  'everyon right seek enjoy countri asylum persecut',
#  'polit refuge may flee live',
#  'the plight boat peopl becam intern humanitarian crisi',
#  'prohibit forcibl return part customari intern law',
#  'onli fraction illeg immigr actual elig asylum statu',
#  "In illeg immigrants' countri origin humanitarian hardship exist",
#  'illeg immigr may serv inform oper hostil state terrorist organ',
#  'immigr contribut congest citi rise crime',
#  'fail stop illeg immigr wave earli stage lead much larger wave illeg immigr futur',
#  'refuge (legal defin peopl persecut origin countri enter anoth countri seek safety) exempt immigr law',
#  'repress intoler immigr solv problem caus econom crisi',
#  'countri must prepar allow open border peopl flee conflict',
#  'refuge much bring countri resettl term cultur labor',
#  'frequently, countri asylum world? poorest nation cannot handl larg influx person',
#  'refuge popul consist peopl terrifi away familiar surround',
#  'applic asylum could deni regardless legitimaci claim',
#  'social polit issu surround issu immigr',
#  'asylum seeker motiv avail benefit',
#  'migrat provid posit resourc economi',
#  'opposit high level immigr refuge base racism',
#  'immigr consid hostil alien natur cultur',
#  'immigr distort spoil exist cultur valu',
#  'immigr acquir job would otherwis avail nativ citizens, suppress wage',
#  'immigr damag sen commun nation',
#  'immigr may overpopul countri',
#  'immigr swamp nativ popul replac cultur',
#  'immigr "swamp" local popul',
#  'everyon exercis right seek asylum find safe refug anoth state',
#  'the system monarchi sinc antiqu contrast form democraci',
#  'the monarch serv ceremoni figurehead symbol nation uniti state continu',
#  'morally-based, balanc monarchi stress ideal form govern',
#  'the hereditari natur monarchi said conflict egalitarian dislik inherit privileg',
#  'the law success held sexist',
#  'monarch may strictli ceremoni duti',
#  'A monarch serv tradit role embodi repres nation',
#  'monarchi sourc check balanc elect politician might seek power excess confer respect constitut',
#  'monarchi check possibl illeg action politician',
#  'monarch cannot prosecut crimin offenc',
#  'social tradit hierarchi essenti social order',
#  'monarch rule intent improv live subject',
#  'the sovereign know interest subject better',
#  'the monarchi work well',
#  'monarchi outdat regress institut',
#  'royal simpli celebr formal role',
#  'constitut monarchi outdat',
#  'republican next logic step toward fulli democrat constitut',
#  'monarchi unfair elitist',
#  'modern democrat societi one expect defer anoth simpli birth',
#  'monarchi encourag attitud suit bygon age imperi',
#  'maintain privileg royal famili diminish societi',
#  'monarchi encourag feel depend mani peopl instead confid fellow citizen',
#  "people', member one family, sovereign",
#  'monarchi contradict democraci',
#  'fundament right peopl nation elect head state everi citizen elig hold offic',
#  'monarch prerog power use circumv normal democrat process account',
#  'monarchi ethnic-discrimin',
#  'monarchi gender-discrimin',
#  'A monarchi demand defer',
#  'monarchi enemi merit aspir',
#  'monarchi devalu intellect achiev',
#  'monarchi harm monarch',
#  'hereditari system condemn heir throne abnorm childhood',
#  'monarch lack account',
#  'monarch imparti',
#  'monarch account',
#  'monarchi expens',
#  'monarchi archaic',
#  'monarchi provid safeguard govern instabl',
#  'monarchi safeguard constitut right individu',
#  'monarchi provid imparti arbit',
#  'A monarch act effect intermediari vaiou level govern polit parti',
#  'crown guarantor misus constitut power politician',
#  'monarchi provid focal point uniti tradit',
#  'A constitut monarch limit power non-partisan natur provid focu nation uniti',
#  'monarchi provid continu stabil',
#  'have long serv monarch increas sen duti continu stabil nation',
#  'monarchi impetu significantli greater nation incom tourism',
#  'monarchi inher contrari egalitarian multicultur',
#  'nation pride diminish monarchi',
#  'monarchi unfashion',
#  'peopl given greater digniti choos head state',
#  'hereditari success outdat',
#  "country' head state elect",
#  'monarchi view outdat irrelev',
#  'the monarchi remain symbol imperi coloni',
#  'the princip advantag hereditari monarchi immedi continu leadership',
#  'monarchi strengthen popular liberti',
#  'the monarch immun crimin prosecut',
#  'republ "inevit',
#  'A singl elect parti nomine select nonparti member could enough destroy parti',
#  "A party' basic function choos leader",
#  'the open primari seen good voter particip',
#  'open primari allow nonpartisan independ voter particip nomin process',
#  'If nonpartisan independ voter allow help select nomine may like vote gener elect',
#  'voter particip unit state higher peopl could vote primari parti',
#  'with open primari voter becom independ le like particip nomin elect process',
#  'open primari leav parti nomin vulner manipul dilut',
#  'open primari may dilut vote particular parti lead nomine repres view particular parti',
#  'open primari unconstitut',
#  'open primari statut unconstitut',
#  'An open primari law gener unconstitut',
#  "voter one parti sometim vote party' primari nomin candid easi favorit beat",
#  'the male condom provid excel protect sexual transmit infect',
#  'barrier contracept may increas risk pregnanc complic',
#  'abstin way avoid sexual transmit diseas',
#  'the use condom encourag prevent transmiss hiv',
#  'condom wide recommend prevent sexual transmit diseas',
#  'cathol church activ support condom use prevent diseas',
#  'condom-promot program encourag promiscu',
#  'condom may interfer process patern toler',
#  'condom featur help prevent spread sexual transmit diseas',
#  'condom (male female) use protect sti',
#  'the best way prevent infect infect someon sti use protect sexual intercours',
#  'proper use condom reduc contact risk',
#  'the major hiv infect acquir unprotect sexual relat partner',
#  'catholic consid form birth control sin',
#  'contracept immor',
#  'condom save life',
#  'condom protect sexual transmit diseas',
#  'condom prevent sexual transmit infect',
#  'sexual act must "retain intrins relationship procreat human life',
#  'contracept "contradict author life [god',
#  'intercours must renew consumm marriag open procreat',
#  'sinc artifici contracept expressli prevent creation new life (and, church would argue, remov sovereignti god creation), contracept unaccept',
#  'use condom sex moral contracept thu sin',
#  'condom imped procr aspect sexual act understood church deepli theolog mean',
#  'permit condom use method prevent diseas could interpret permit fornic',
#  'promot condom use lead irresponsible, riski sexual behavior',
#  'condom sin circumst',
#  'the church..ha respect respons decision-mak coupl',
#  'condom accept mean prevent aid',
#  'condom use prevent spread hiv',
#  'condom use could encourag spread hiv promot extramarit sex',
#  'condom use prevent spread aid',
#  'church\' ban condom "caus death million',
#  'god creat sexual intercours unit procr',
#  "act deliber attempt divorc unit procr mean marit act oppos god' plan life",
#  'cathol church support condom use prevent seriou diseas aids, non-us tantamount murder',
#  "there reason conclud natur famili plan appropri 'artificial' mean",
#  'birth control could open wide way marit infidel',
#  'man grow accustom use contracept method may forget rever due woman',
#  'contracept alway serious evil',
#  'contracept grave oppos marit chastiti',
#  'contracept contrari good transmiss life',
#  'contracept deni sovereign role god transmiss human life',
#  'cathol church support condom use prevent seriou diseas aid',
#  'birth control, forms, sin',
#  'licit sexual act must open procreat',
#  'licit sexual act must unit (express love), procr',
#  'church could chang long-stand teach',
#  'person use condom protect spread infect',
#  'the problem aid cannot overcom distribut prophylactics: contrary, increas',
#  'rais school leav age tackl problem young peopl leav school unskil',
#  'histori drive compulsori school guid altruism, desir coerc popul mold desir establish',
#  'youth right control direct learn',
#  'current compulsori school system violat basic fundament right humans: right decid enter mind',
#  'freedom learn part freedom thought',
#  'forc schooling, regardless whether student learn anyth whatsoever, student could effect learn elsewher differ ways, gross violat civil liberti',
#  'school inhibit person’ abil self-learn',
#  'forc school pervert victims’ natur inclin grow learn',
#  'high rate educ essenti countri abl achiev high level econom growth',
#  "releas tactic inform usual present greater risk casualti among one' forc",
#  'right freedom speech absolut',
#  'must constraint free flow inform idea',
#  'democraci true essenti ideal power abl manipul elector withhold inform',
#  'access inform increasingli recognis prerequisit transpar account govern',
#  'access inform basic human right',
#  'the right govern forbid public properli categor state secret recognis',
#  'freeli inform flows, stronger societi becom',
#  'govern may distinguish materi public protect disclosur public',
#  'the individu freedom express essenti well-b societi',
#  'the purpos classif protect inform use damag endang nation secur',
#  'nation security" may simpli serv pretext suppress unfavor polit social view',
#  'everyon right freedom opinion express',
#  'inform free',
#  'leak .. may neg secur impact peopl involv',
#  'the decis leak classifi inform someth illeg',
#  'individu make judgment threat inform qualifi make',
#  'howev illeg document came light, rais seriou question',
#  'free speech regul govern regul law',
#  'the purpos censorship prevent public secur inform could benefit enemi harm state',
#  'precis repercuss decis secur natur life nation, suitabl open door openli exchang view secur issu',
#  'author exercis censorship press .. absolut necessari public safeti',
#  'govern inform avail public',
#  'valuabl farmland go wast use recreat drug instead use plant food crop',
#  'smoke consid immor habit',
#  'subsidi may distort markets, impos larg econom cost',
#  'subsidi may distort market produc ineffici',
#  'tobacco use describ singl import prevent risk human health develop countri',
#  'the cultiv tobacco econom detriment develop countri',
#  'when resourc put tobacco product taken away food product',
#  'A larg percent profit tobacco product go larg tobacco compani rather local tobacco farmer',
#  'govern subsid tobacco farm make econom sen',
#  'the cultiv tobacco econom detriment countri produc',
#  'when resourc put tobacco production, taken away food product',
#  'the market system adequ reward farm peopl agricultur commod',
#  'smoke tobacco among lead caus mani diseas',
#  'tobacco-rel diseas biggest killer world today',
#  'toxic compound tobacco constitut seriou health hazard',
#  'subsidi provid littl benefit farmer',
#  'tobacco singl greatest caus prevent death global',
#  'tobacco use describ singl import prevent risk human health',
#  'tobacco consid usurp good farm land',
#  'cigarett smoke produc substanti health-rel econom cost societi',
#  'tobacco play import role economi produc area',
#  'tobacco caus cancer',
#  'commerci tobacco product vital part american world economi',
#  'smoking-rel health problem contribut rise health care cost',
#  'subsidis agricultur develop world one greatest obstacl econom growth develop world',
#  'artifici low price result subsidi creat unhealthi incent consum',
#  'subsidi ineffici use taxpayer’ money',
#  'thing unlimit freedom',
#  'the free commun thought opinion one preciou right man',
#  'freedom express absolut limit certain situat',
#  'limit freedom speech prescrib law permit justifi reason limit',
#  'freedom express subject certain restrict',
#  'censorship occasion carri aid author protect individu',
#  'freedom speech may restrict law protect right respect other',
#  'human right limit even push asid time nation emerg',
#  'government-enforc right access inescap dampen vigor limit varieti public debat',
#  'everyon right freedom opinion express',
#  'effort limit use word languag actual form restrict freedom thought',
#  'limit free speech balanc right free speech right',
#  'govern may censor speech speech',
#  'freedom speech, order exist function, necessarili extend even unpopular',
#  'individu must unlimit access idea fellow men “a free open encount',
#  'the individu freedom express essenti well-b societi',
#  'freedom restrict reason "sovereignti integr',
#  'the peopl depriv abridg right speak, write, publish sentiment',
#  'nation war, mani thing might said time peac hindranc effort utter endur long men fight',
#  'circumst wartim permit greater restrict free speech would allow peacetim',
#  'the right free speech conflict right',
#  'freeli express word direct threat human right',
#  'the free commun idea opinion one preciou right man',
#  'the right freedom speech express may limit conflict right',
#  'express dissent subvers view toler',
#  'free discus necessari prevent "deep slumber decid opinion',
#  'speech justifi suppress order prevent harm clear direct threat',
#  'must constraint free flow inform idea',
#  'democraci true essenti ideal power abl manipul elector withhold inform stifl critic',
#  'freedom speech help provid balanc stabil chang',
#  'ought exist fullest liberti profess discussing, matter ethic conviction, doctrine, howev immor may consid',
#  'form express legitim prohibit law offens',
#  'freedom speech fundament human right',
#  'necessari prevent use inform resourc technolog crimin terrorist purpos',
#  'freeli inform flows, stronger societi becom',
#  'No human right basic freedom express',
#  'clear present danger pose discriminatori speech growth e-hat',
#  'freedom express lifeblood free open societi',
#  "liberti express 'i absolut",
#  'govern may prohibit express idea simpli societi find idea offens disagre',
#  'punish danger offens write necessari preserv peac good order',
#  'reason restrict upon free speech serv public order',
#  'freedom speech press lay foundat democrat organis',
#  'the freedom speech press confer absolut right express without respons',
#  'reason restrict impos freedom speech expression, interest secur state',
#  'all utter intend endang secur state may restrain interest secur state',
#  'freedom speech allow person contempt court',
#  'freedom speech express excus distribut indec immor content',
#  'reason restrict freedom express impos interest public order',
#  'censorship violat multipl basic human right',
#  'one toler free speech concern drug',
#  'freedom speech heart democraci',
#  'right freedom speech subject limit hate speech',
#  'without restrictions, total freedom speech would allow freedom slander',
#  'press freedom right peopl',
#  'unemploy increas govern interven economi tri improv condit without job',
#  'the american job act, would give busi incent hire unemploy disabl veteran',
#  'the american job act give tax breaks, thu contribut feder deficit',
#  'improv economy, policymak focu reform remov impedi work',
#  'voucher form publicli fund privat school choic necessari give famili opportun enrol child effect privat school',
#  'voucher system public educ would make public school compet one anoth thu make account effici',
#  'distribut voucher famili student equal tuition he/sh would receiv his/her local public school, student’ famili could choos option best send child',
#  'public educ would destroy tuition voucher',
#  'tuition voucher propos would undermin public educ',
#  'competit among school increas qualiti econom effici public educ',
#  'voucher function increas racial econom discrimin school',
#  'sinc approxim four five US privat school religious, voucher charter system violat constitut',
#  '"competit educ market" would lead "innov improv',
#  'allow famili option public privat school undermin public educ system',
#  'competit would improv school cost effici',
#  'school voucher educ tax credit system incentiv school increas account school perform',
#  'competit spur voucher educ tax credit increas qualiti elig privat school local public school',
#  'both privat public school improv use voucher',
#  'voucher improv academ outcom public school',
#  'voucher reduc racial segreg',
#  'voucher deliv better servic special educ student',
#  'school voucher would erod educ standard reduc fund',
#  'voucher system would weaken public school',
#  'grant govern money, even indirectly, privat religi school inevit lead increas government control non-govern educ',
#  'competit student (and educ dollar come them) creat catalyst school creat innov program',
#  'school choic program would allow poor student opt bad school acquir better educ',
#  'freedom educ notabl impli freedom parent choos school child without discrimin basi financ',
#  'voucher could result noth cash-handout mani middle-class wealthi famili alreadi send kid privat school',
#  'through free competit vendor provis product services, price tend decrease, qualiti tend increas',
#  'famili forc send kid school know fail',
#  'feder school voucher inevit come central govern regul loss local control educ',
#  'educ voucher would undermin public school',
#  'access resourc play huge import role educ inequ',
#  'educ system forc low-incom famili place child less-than-id school system',
#  'politician often accus misus alloc selfish purpos',
#  'earmark good american democraci',
#  'reduc earmark reduc govern spend',
#  'In alreadi flaw system, earmark least allow resid congression district greater role alloc feder fund',
#  'direct money particular purpos core constitut function congress',
#  'congressman tend distribut special benefit great cost ignor particular cost legisl bear upon taxpay',
#  'benefit vote reach particular portion population, tax cost pay vote spread throughout entir populac',
#  'committe member exploit pork barrel project elector purpos',
#  "power purs one congress' primari check execut branch",
#  'deployment, implicit menac use, strong weapon essenti threaten enemi order prevent use said-enemi weapon',
#  'nuclear nation might hijack despot person person might use nuclear weapon without sane regard consequ',
#  'have nuclear nuclear-weapon state reduc secur',
#  'nuclear forc continu play essenti role war prevent',
#  'relianc nuclear weapon deterr becom increasingli hazard decreasingli effect',
#  'the world new danger nuclear era, likelihood non-stat terrorist get hand nuclear weaponri increas',
#  'nuclear weapon technolog would soon reach point could end human life earth',
#  'nuclear holocaust could result end human life',
#  'nuclear weapon becom sourc extrem risk',
#  'nuclear weapon induc stabil',
#  'nuclear weapon decreas chanc crisi escal',
#  'control nuclear prolifer may benefici induc stabil',
#  'nuclear prolifer increas chanc inter-st nuclear conflict',
#  'nuclear prolifer increas chanc nuclear materi fall hand non-stat group',
#  'new nuclear state use acquir nuclear capabl deter threat preserv peac',
#  'new nuclear state often lack adequ organiz control new weapon',
#  "nuclear weapon may lessen state' relianc alli security, thu prevent alli drag war",
#  'nuclear weapon induc stabil regim',
#  'nuclear weapon contribut stabil strateg level',
#  'public opinion overwhelmingli oppos nuclear',
#  'state must act way ensur secur',
#  'state cannot count good other help them, must alway readi fend',
#  'present situat wherebi nuclear weapon state monopolis right posse nuclear weapon "highli discriminatori',
#  'countri nuclear weapon may increas possibl nuclear warfar',
#  'the spread nuclear weapon increas intern stabil',
#  'nuclear prolifer decreas likelihood war',
#  'state posit safe guard nuclear use',
#  'the effect prohibit nuclear prolifer characteris form technolog apartheid',
#  'signific nuclear weapon pure deter war',
#  'the use (or threat use of) nuclear weapon would gener contrari rule intern law applic arm conflict',
#  'unlik convent weapons, nuclear weapon success deter all-out war state',
#  'nuclear disarma would undermin deterr',
#  'nuclear disarma could lead increas global instabl',
#  'inferior nuclear force, virtu extrem destruct power, could deter power adversari',
#  'nuclear weapon becom sourc extrem risk',
#  'nuclear weapon intend deter state attack',
#  'nuclear weapon give nation potenti destroy enemi human',
#  'extrem danger intrins nuclear war posse nuclear weapon',
#  'nuclear weapon wide available, deterr decreasingli effect increasingli hazard',
#  'hope escap self-destruction, nuclear weapon place collect conscience, role secur',
#  'full-scal nuclear war could potenti bring extinct human race',
#  'full-scal nuclear war would result extinct human speci',
#  'greater threat mutual destruction, safer world would',
#  'two countri nuclear weapons, probabl direct war greatli decreas',
#  'collect bargain "in public interest',
#  'collect bargain contribut effect conduct public busi',
#  'collect bargain facilit encourag amic settlement disput employe employ',
#  'union frequent produc higher wage expens fewer job',
#  'union promot deadweight loss',
#  'the effect union activ influenc price potenti harm',
#  'union worker rais wage natur rate expens busi worker',
#  'union never rais product compens higher wage',
#  'union worker spend higher wages, drive econom growth creat new job',
#  'union may serv practic purpos level playing-field worker power oligopoli',
#  'inher right collect bargain',
#  'unionis produc higher wage (for union members) expens fewer job',
#  'individu cannot stand alon power compani',
#  'the right collect bargain recogn intern human right convent',
#  'the freedom associ effect recognit right collect bargain defin essenti right worker',
#  'collect bargain regard human right',
#  'the right bargain collect employ enhanc human digniti',
#  'collect bargain intrins valuabl experi self-govern',
#  'collect bargain permit worker achiev form workplac democraci',
#  'abort neg effect societi',
#  'state interest preserv fetal life',
#  'intact dilat extract never need protect health pregnant woman',
#  'partial-birth abort .. .. unnecessari preserv health mother',
#  'A partial-birth abort bear relev measur need advanc health woman',
#  'abort caus mental health problem',
#  'right person privaci includ abort decis',
#  'fundament right privaci encompass decis abort',
#  'abort legal circumst',
#  'unborn child inher right life',
#  'abortion, especi late-term abortion, unjust',
#  'critic consid idx procedur infanticid',
#  'abort legal circumst',
#  'the govern interfer woman’ abil abort',
#  'the human fetu person therefor right life',
#  'whether continu pregnanc inviol person choic',
#  'legal abort medic control condit prefer illeg back-alley abort without proper medic supervis',
#  'certain restrict abort could use form slipperi slope abort',
#  "women' live lost due unsaf abort abort illeg",
#  'life begin concept',
#  'abortion, would involv deliber destruct life, reject',
#  'abort approv disapprov accord circumst',
#  'one must abort fetu continu pregnanc might imperil life woman',
#  'abort justifi continu pregnanc might caus woman sever physic psycholog harm',
#  "In circumstances, woman' decis whether termin pregnanc",
#  'decis left woman within whose bodi fetu grow',
#  'abort deem fundament right',
#  'decis abort must left mother physician',
#  "A state' ban partial birth abort unconstitut",
#  'moral right life human be (human organisms) begin near conception-fertil',
#  'induc abort deliber unjust kill embryo violat right life',
#  'woman right control happen bodi',
#  'law crimin exercis right control one’ bodi',
#  'crimin abort lead death mani woman ‘back-alley abort',
#  'embryo right life',
#  'right life begin concept',
#  'abort wrong depriv embryo valuabl futur',
#  'standard embryo highli valuabl future, kill serious wrong',
#  'deliber abort serious immor',
#  'fetu right life',
#  'illeg govern regul abort',
#  'state "import legitim interest protect potenti human life',
#  'state interest protect fetu "at point", interest cannot overrid pregnant woman',
#  'abort moral wrong',
#  'fetu innoc biolog human, person right life',
#  'A right life begin concept',
#  'abort involv unjust discrimin unborn',
#  'deliber abort place "same moral category" kill innoc adult human',
#  'abort equival conscious take risk kill anoth',
#  'abort consid moral wrong',
#  'A state law ban certain form abort unconstitut',
#  'd&x would safer would involv fewer risk woman',
#  'd&x abort never medic necessari',
#  'govern right forc doctor perform procedur felt would safest',
#  'work parent wish child supervis',
#  'summer vacat period students’ rate academ develop declin rel school year',
#  'all child lose academ skill summer month',
#  'child need 2–3 month relax also take break childhood stress associ school',
#  'multitrack schedul reportedli bring mani benefit school use',
#  'everi three multitrack schools, one le school must built',
#  'students’ attitud toward school significantli increas spent time year-round schedul',
#  'student attend year-round school say calendar balanc peer typic school calendar',
#  'year-round school show substanti gain academ achiev at-risk, low perform student',
#  'more frequent, short break provid struggl student time help',
#  'parent favor year-round schedul',
#  'the year round schedul provid opportun famili vacat',
#  'If school open longer oper mainten cost may increas',
#  'year round school may creat difficulti teen abl maintain part-tim summer job',
#  'student attent learn disabl may experi difficulti longer school day',
#  'student attend year round school may miss experi',
#  'welfar empow individu',
#  'welfar breed depend govern aid',
#  'welfar breed depend govern',
#  'welfar demonstr proven effect help impoverish famili',
#  'foreign aid seen serv interest donor recipi',
#  'subsidi may distort market',
#  'subsidi may distort market',
#  'subsidi produc ineffici',
#  'subsidi ineffici',
#  'welfar reduc poverti',
#  'welfar sustain even creat poverti',
#  'poverti decreas countri adapt welfar program',
#  'welfar creat depend',
#  'welfar make incent find work',
#  'welfar increas poverti also increas problem',
#  'safeti net redistribut incom poorest vulnerable, immedi impact poverti',
#  'safeti net enabl household make product invest futur may otherwis miss',
#  'cct program prove well-target effect',
#  'cct program effici tool reduc poverti inequ',
#  'subsidi guarante access essenti commod price consum afford',
#  'subsidi tend expens regress',
#  'subsidi may distort product incent',
#  'safeti net protect household face hard time fall deeper poverti help manag risk',
#  'safeti net protect household face hard time fall deeper poverti help manag risk',
#  'safeti net provid household cushion invest resourc effici',
#  'le stratifi economi social',
#  'rich oblig assist poor, thu creat financi egalitarian societi',
#  'rich exploit poor otherwis gain unfair benefits, thu return benefit',
#  'larger middl class benefit economi enabl peopl consum',
#  'econom inequ contribut crime',
#  'lower rate redistribut given societi increas inequ found among futur incom',
#  'wealth incom inequ caus econom crise',
#  'reduc wealth incom inequ one way prevent amelior econom crise',
#  'government redistribut wealth improv social stabil',
#  'encourag receiv aid resum work',
#  'redistribut legitim obtain properti cannot ever',
#  'redistribut tend benefit polit clout set spend prioriti need',
#  'poverty, started, like continu unless outsid intervent',
#  'welfar state produc gener depend who, instead working, reli sole upon state incom',
#  'social welfar creat depend state',
#  'higher level econom inequ tend intensifi social hierarchi gener degrad qualiti social relat',
#  'econom inequ thought reduc distribut effici within societi',
#  'societi equal higher aggreg util',
#  'societi inequ lower, population-wid satisfact happi tend higher',
#  'increas gap rich poor increas incent competit innov within economi',
#  'inequ harm econom develop',
#  'redistribut polici advers effect invest econom growth',
#  'econom equal necessari polit freedom',
#  'econom inequ polit inequ assur',
#  'certain amount redistribut would justifi',
#  "without redistribution, one generation' success individu would becom next generation' embed cast",
#  'social justic requir redistribut high incom larg concentr wealth way spread wide',
#  'econom inequ reduc social cohes increas social unrest',
#  'econom inequ invari translat polit inequ',
#  'the avail govern fund lead tension within commun',
#  "becaus current scienc can't figur exactli life started, must god caus life start",
#  'insuffici ground assert authorit suprem exist',
#  'acknowledg god god major factor motiv peopl toward moral behavior',
#  'atheism critic faith',
#  'atheism systemat influenc peopl bad thing',
#  'the exist god evil logic incompat',
#  'god cannot exist with, would want prevent, evil',
#  'god evil logic incompat',
#  'An omniscient, wholli good would prevent occurr intens suffer',
#  'belief higher product fear',
#  'need god explain thing',
#  'immor act human histori perform atheist',
#  'human race longer need religion',
#  'attempt reconcil faith scienc reason consign failur',
#  'human reason incap provid suffici ration ground justifi belief deiti either exist',
#  'god, begin end all, can, natur light human reason, known certainti work creation',
#  'unproven religi proposit deserv much disbelief unproven proposit',
#  'atheist quick believ god time crisi',
#  'god religi belief human invent',
#  'belief god religion social functions, use power oppress work class',
#  'idea god impli abdic human reason justic',
#  'the idea god decis negat human liberti',
#  'the idea god necessarili end enslav mankind',
#  'deni exist god lead moral relativism, leav one moral ethic foundat',
#  'deni exist god render life meaningless miser',
#  'religion view human invent use frighten peopl follow moral order',
#  'atheism superior basi ethic',
#  'religion provid net benefit individu societi',
#  'religion harm',
#  'relianc divin author lend authoritarian dogmat',
#  'god must exist give forc moral oblig',
#  'object moral truth bind natur oblig suggest high power enforc them, regard god',
#  'exist god orthodoxli conceiv could support exist moral order world',
#  'A natur moral order requir exist god orthodoxli conceived, god must exist',
#  "good argument god' exist aris pure reason alon",
#  'moral thought requir assumpt god exist',
#  'theist abl offer justif morality, atheist',
#  'natur exist',
#  'univers explain without refer supernatur',
#  'god exist proven',
#  "none argument god' exist compel",
#  'life univers creat deiti',
#  "faith − belief base evid − one world' great evil",
#  'atheism evid healthy, independ mind',
#  'noth exist beyond natur univers',
#  ...]

# %%
claim_prepocessed_data =pd.DataFrame(claim_lemmatized_reviews)
dataset2 = data.replace(data['claims.claimCorrectedText'],claim_lemmatized_reviews.values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-aceac3e4ca2a> in <module>
#       1 claim_prepocessed_data =pd.DataFrame(claim_lemmatized_reviews)
# ----> 2 dataset2 = data.replace(data['claims.claimCorrectedText'],claim_lemmatized_reviews.values)
#
# AttributeError: 'list' object has no attribute 'values'

# %%
dataset2
# Out:
#       topicId  split                                          topicText  \
# 0           1   test  This house believes that the sale of violent v...
# 1           1   test  This house believes that the sale of violent v...
# 2           1   test  This house believes that the sale of violent v...
# 3           1   test  This house believes that the sale of violent v...
# 4           1   test  This house believes that the sale of violent v...
# 5           1   test  This house believes that the sale of violent v...
# 6           1   test  This house believes that the sale of violent v...
# 7           1   test  This house believes that the sale of violent v...
# 8           1   test  This house believes that the sale of violent v...
# 9           1   test  This house believes that the sale of violent v...
# 10          1   test  This house believes that the sale of violent v...
# 11          1   test  This house believes that the sale of violent v...
# 12          1   test  This house believes that the sale of violent v...
# 13          1   test  This house believes that the sale of violent v...
# 14          1   test  This house believes that the sale of violent v...
# 15          1   test  This house believes that the sale of violent v...
# 16          1   test  This house believes that the sale of violent v...
# 17          1   test  This house believes that the sale of violent v...
# 18          1   test  This house believes that the sale of violent v...
# 19          1   test  This house believes that the sale of violent v...
# 20          1   test  This house believes that the sale of violent v...
# 21          1   test  This house believes that the sale of violent v...
# 22          1   test  This house believes that the sale of violent v...
# 23          1   test  This house believes that the sale of violent v...
# 24          1   test  This house believes that the sale of violent v...
# 25          1   test  This house believes that the sale of violent v...
# 26          1   test  This house believes that the sale of violent v...
# 27          1   test  This house believes that the sale of violent v...
# 28          1   test  This house believes that the sale of violent v...
# 29          1   test  This house believes that the sale of violent v...
# ...       ...    ...                                                ...
# 2364     1065  train           This house would promote democratization
# 2365     1065  train           This house would promote democratization
# 2366     1065  train           This house would promote democratization
# 2367     1065  train           This house would promote democratization
# 2368     1065  train           This house would promote democratization
# 2369     1065  train           This house would promote democratization
# 2370     1065  train           This house would promote democratization
# 2371     1065  train           This house would promote democratization
# 2372     1065  train           This house would promote democratization
# 2373     1065  train           This house would promote democratization
# 2374     1065  train           This house would promote democratization
# 2375     1065  train           This house would promote democratization
# 2376     1065  train           This house would promote democratization
# 2377     1065  train           This house would promote democratization
# 2378     1065  train           This house would promote democratization
# 2379     1065  train           This house would promote democratization
# 2380     1065  train           This house would promote democratization
# 2381     1065  train           This house would promote democratization
# 2382     1065  train           This house would promote democratization
# 2383     1065  train           This house would promote democratization
# 2384     1065  train           This house would promote democratization
# 2385     1065  train           This house would promote democratization
# 2386     1065  train           This house would promote democratization
# 2387     1065  train           This house would promote democratization
# 2388     1065  train           This house would promote democratization
# 2389     1065  train           This house would promote democratization
# 2390     1065  train           This house would promote democratization
# 2391     1065  train           This house would promote democratization
# 2392     1065  train           This house would promote democratization
# 2393     1065  train           This house would promote democratization
#
#                                     topicTarget  topicSentiment  \
# 0     the sale of violent video games to minors              -1
# 1     the sale of violent video games to minors              -1
# 2     the sale of violent video games to minors              -1
# 3     the sale of violent video games to minors              -1
# 4     the sale of violent video games to minors              -1
# 5     the sale of violent video games to minors              -1
# 6     the sale of violent video games to minors              -1
# 7     the sale of violent video games to minors              -1
# 8     the sale of violent video games to minors              -1
# 9     the sale of violent video games to minors              -1
# 10    the sale of violent video games to minors              -1
# 11    the sale of violent video games to minors              -1
# 12    the sale of violent video games to minors              -1
# 13    the sale of violent video games to minors              -1
# 14    the sale of violent video games to minors              -1
# 15    the sale of violent video games to minors              -1
# 16    the sale of violent video games to minors              -1
# 17    the sale of violent video games to minors              -1
# 18    the sale of violent video games to minors              -1
# 19    the sale of violent video games to minors              -1
# 20    the sale of violent video games to minors              -1
# 21    the sale of violent video games to minors              -1
# 22    the sale of violent video games to minors              -1
# 23    the sale of violent video games to minors              -1
# 24    the sale of violent video games to minors              -1
# 25    the sale of violent video games to minors              -1
# 26    the sale of violent video games to minors              -1
# 27    the sale of violent video games to minors              -1
# 28    the sale of violent video games to minors              -1
# 29    the sale of violent video games to minors              -1
# ...                                         ...             ...
# 2364                            democratization               1
# 2365                            democratization               1
# 2366                            democratization               1
# 2367                            democratization               1
# 2368                            democratization               1
# 2369                            democratization               1
# 2370                            democratization               1
# 2371                            democratization               1
# 2372                            democratization               1
# 2373                            democratization               1
# 2374                            democratization               1
# 2375                            democratization               1
# 2376                            democratization               1
# 2377                            democratization               1
# 2378                            democratization               1
# 2379                            democratization               1
# 2380                            democratization               1
# 2381                            democratization               1
# 2382                            democratization               1
# 2383                            democratization               1
# 2384                            democratization               1
# 2385                            democratization               1
# 2386                            democratization               1
# 2387                            democratization               1
# 2388                            democratization               1
# 2389                            democratization               1
# 2390                            democratization               1
# 2391                            democratization               1
# 2392                            democratization               1
# 2393                            democratization               1
#
#       claims.claimId claims.stance  \
# 0               2973           PRO
# 1               2974           CON
# 2               2975           CON
# 3               2977           PRO
# 4               2978           PRO
# 5               2979           CON
# 6               2980           PRO
# 7               2981           PRO
# 8               2982           PRO
# 9               2983           PRO
# 10              2985           CON
# 11              2986           CON
# 12              2987           CON
# 13              2988           CON
# 14              2989           CON
# 15              2990           CON
# 16              2991           PRO
# 17              2992           PRO
# 18              2993           PRO
# 19              2994           CON
# 20              2995           PRO
# 21              2996           PRO
# 22              2997           PRO
# 23              2998           CON
# 24              2999           CON
# 25              3000           CON
# 26              3001           CON
# 27              3002           CON
# 28              3003           CON
# 29              3004           CON
# ...              ...           ...
# 2364          608887           PRO
# 2365          608889           CON
# 2366          608890           PRO
# 2367          608891           PRO
# 2368          608892           PRO
# 2369          608893           CON
# 2370          610382           PRO
# 2371          610567           CON
# 2372          610568           CON
# 2373          610569           PRO
# 2374          610571           PRO
# 2375          610572           PRO
# 2376          610573           CON
# 2377          610575           PRO
# 2378          610576           PRO
# 2379          610577           PRO
# 2380          610578           PRO
# 2381          610580           PRO
# 2382          611772           PRO
# 2383          611773           CON
# 2384          611774           CON
# 2385          611892           PRO
# 2386          611893           CON
# 2387          612045           PRO
# 2388          612084           CON
# 2389          612112           CON
# 2390          612113           CON
# 2391          612114           CON
# 2392          612555           PRO
# 2393          612556           CON
#
#                               claims.claimCorrectedText  \
# 0     Exposure to violent video games causes at leas...
# 1     video game violence is not related to serious ...
# 2     some violent video games may actually have a p...
# 3     exposure to violent video games causes both sh...
# 4     Violent video games increase the violent tende...
# 5     No conclusive link was found between video gam...
# 6     violent video games are significantly associat...
# 7     video game publishers unethically train childr...
# 8     violent video games may increase mild forms of...
# 9     exposure to violent video games results in inc...
# 10    No long-term relationship was found between pl...
# 11    aggressive children tend to select more violen...
# 12    No evidence has found that violent games are p...
# 13    adolescents that don't play video games at all...
# 14    video game play is part of an adolescent boy's...
# 15    Biological theories of aggression and violence...
# 16    Reinforcement of sexist stereotypes has been c...
# 17    A correlation was found between children playi...
# 18    violent video games can increase children's ag...
# 19    Media influences are too weak and distant to h...
# 20    violent video games promote violent behavior, ...
# 21    Excessive exposure to violent video games and ...
# 22    Neurological link was found between playing vi...
# 23    There is no direct link between violent video ...
# 24    Video games develop the individual's intelligence
# 25    violent games help students deal with stress a...
# 26    violent games affect students positively and n...
# 27    many skills can be learned from the gaming exp...
# 28    media cannot cause violence because humans hav...
# 29    video games have many healthy and positive asp...
# ...                                                 ...
# 2364                        democracy would bring peace
# 2365                           democracy leads to chaos
# 2366  the inclusive nature of democracy can lift the...
# 2367  democracy can help to build trust and settle o...
# 2368         democracy can be a path to lasting justice
# 2369  no system of government can or should be impos...
# 2370  democratic nations have much less democide or ...
# 2371  democracies would be inherently unstable and c...
# 2372              Democracy is contrary to human nature
# 2373       majority rule is preferable to other systems
# 2374  democracy leads to less internal violence and ...
# 2375  democracy aims at reducing political uncertain...
# 2376  democracy could be easily exploited by leaders...
# 2377  A democratic system may provide better informa...
# 2378  The democratic system provides a way to replac...
# 2379          more democracy increases economic freedom
# 2380  Democracies have the potential to put in place...
# 2381  Democratic nations have less genocide and poli...
# 2382  only in a democracy the citizens can have a sh...
# 2383  the concept of democracy as a constant process...
# 2384  democratic institutions would do no more than ...
# 2385  democracy has repeatedly proven to be a fundam...
# 2386    democracy is actually a decline of civilization
# 2387  people must have the opportunity to decide wha...
# 2388                Democracy is reckless and arbitrary
# 2389  democracies have ever been found incompatible ...
# 2390  democracy cannot subsist long nor be carried f...
# 2391  Democracy in general is criticized for ignorin...
# 2392  democracy and freedom are indispensable ingred...
# 2393           democracy cannot be imposed from outside
#
#                                claims.claimOriginalText  \
# 0     exposure to violent video games causes at leas...
# 1     video game violence is not related to serious ...
# 2     some violent video games may actually have a p...
# 3     exposure to violent video games causes both sh...
# 4      they increase the violent tendencies among youth
# 5     have shown no conclusive link between video ga...
# 6     violent video games are significantly associat...
# 7     video game publishers unethically train childr...
# 8     violent video games may increase mild forms of...
# 9     exposure to violent video games results in inc...
# 10    no long-term relationship between playing viol...
# 11    aggressive children tend to select more violen...
# 12    no evidence violent games are psychologically ...
# 13    adolescents that don't play video games at all...
# 14    video game play is part of an adolescent boy's...
# 15    Other biological theories of aggression and vi...
# 16    Reinforcement of sexist stereotypes has also b...
# 17    a correlation between children playing violent...
# 18    violent video games can increase children's ag...
# 19    media influences are too weak and distant to h...
# 20    violent video games promote violent behavior, ...
# 21    Excessive exposure to violent video games and ...
# 22    neurological link between playing violent vide...
# 23    there was no direct link between violent video...
# 24    Video games also develop the individual's inte...
# 25    violent games help students deal with stress a...
# 26    violent games affect students positively and n...
# 27    many skills can be learned from the gaming exp...
# 28    media cannot cause violence because humans hav...
# 29    video games have many healthy and positive asp...
# ...                                                 ...
# 2364                        democracy would bring peace
# 2365                           democracy leads to chaos
# 2366  the inclusive nature of democracy can lift the...
# 2367  democracy can help to build trust and settle o...
# 2368         democracy can be a path to lasting justice
# 2369  no system of government can or should be impos...
# 2370  democratic nations have much less democide or ...
# 2371  democracies would be inherently unstable and c...
# 2372             democracy was contrary to human nature
# 2373       majority rule is preferable to other systems
# 2374  democracy leads to less internal violence and ...
# 2375  democracy aims at reducing political uncertain...
# 2376  democracy could be easily exploited by leaders...
# 2377  A democratic system may provide better informa...
# 2378  The democratic system also provides a way to r...
# 2379          more democracy increases economic freedom
# 2380  Democracies have the potential to put in place...
# 2381             they have less genocide and politicide
# 2382  only in a democracy the citizens can have a sh...
# 2383  the concept of democracy as a constant process...
# 2384  democratic institutions would do no more than ...
# 2385  democracy has repeatedly proven to be a fundam...
# 2386    democracy is actually a decline of civilization
# 2387  people must have the opportunity to decide wha...
# 2388               democracy was reckless and arbitrary
# 2389  democracies have ever been found incompatible ...
# 2390  democracy cannot subsist long nor be carried f...
# 2391  democracy in general for ignoring the rights o...
# 2392  democracy and freedom are indispensable ingred...
# 2393           democracy cannot be imposed from outside
#
#            claims.article.rawFile  ...  claims.article.rawSpan.end  \
# 0           articles/t1/raw_1.txt  ...                         640
# 1           articles/t1/raw_1.txt  ...                        1697
# 2           articles/t1/raw_1.txt  ...                        2089
# 3           articles/t1/raw_1.txt  ...                        3695
# 4           articles/t1/raw_1.txt  ...                        8167
# 5           articles/t1/raw_1.txt  ...                        9167
# 6           articles/t1/raw_1.txt  ...                       11587
# 7           articles/t1/raw_1.txt  ...                       13905
# 8           articles/t1/raw_1.txt  ...                       14480
# 9           articles/t1/raw_1.txt  ...                       14664
# 10          articles/t1/raw_1.txt  ...                       18657
# 11          articles/t1/raw_1.txt  ...                       19010
# 12          articles/t1/raw_1.txt  ...                       19092
# 13          articles/t1/raw_1.txt  ...                       19910
# 14          articles/t1/raw_1.txt  ...                       20033
# 15          articles/t1/raw_1.txt  ...                       25154
# 16          articles/t1/raw_1.txt  ...                       31212
# 17          articles/t1/raw_1.txt  ...                       34209
# 18          articles/t1/raw_1.txt  ...                       34454
# 19          articles/t1/raw_1.txt  ...                       62297
# 20          articles/t1/raw_1.txt  ...                       63233
# 21          articles/t1/raw_1.txt  ...                       69786
# 22          articles/t1/raw_1.txt  ...                       70530
# 23          articles/t1/raw_1.txt  ...                       72138
# 24          articles/t1/raw_1.txt  ...                       73685
# 25          articles/t1/raw_1.txt  ...                       74122
# 26          articles/t1/raw_1.txt  ...                       74358
# 27          articles/t1/raw_1.txt  ...                       76880
# 28          articles/t1/raw_1.txt  ...                       77813
# 29          articles/t1/raw_1.txt  ...                       79120
# ...                           ...  ...                         ...
# 2364  articles/t1065/raw_3651.txt  ...                       21836
# 2365  articles/t1065/raw_3651.txt  ...                       22595
# 2366  articles/t1065/raw_3651.txt  ...                       22906
# 2367  articles/t1065/raw_3651.txt  ...                       23154
# 2368  articles/t1065/raw_3651.txt  ...                       23351
# 2369  articles/t1065/raw_3651.txt  ...                       26220
# 2370  articles/t1065/raw_3720.txt  ...                       10405
# 2371  articles/t1065/raw_3653.txt  ...                        9104
# 2372  articles/t1065/raw_3653.txt  ...                        9175
# 2373  articles/t1065/raw_3653.txt  ...                       47696
# 2374  articles/t1065/raw_3653.txt  ...                       48094
# 2375  articles/t1065/raw_3653.txt  ...                       48503
# 2376  articles/t1065/raw_3653.txt  ...                       49505
# 2377  articles/t1065/raw_3653.txt  ...                       52515
# 2378  articles/t1065/raw_3653.txt  ...                       52758
# 2379  articles/t1065/raw_3653.txt  ...                       56480
# 2380  articles/t1065/raw_3653.txt  ...                       62194
# 2381  articles/t1065/raw_3653.txt  ...                       65196
# 2382  articles/t1065/raw_3652.txt  ...                       59204
# 2383  articles/t1065/raw_3652.txt  ...                       75747
# 2384  articles/t1065/raw_3652.txt  ...                       76715
# 2385  articles/t1065/raw_3721.txt  ...                        3431
# 2386  articles/t1065/raw_3721.txt  ...                       12962
# 2387  articles/t1065/raw_4078.txt  ...                        4527
# 2388  articles/t1065/raw_4080.txt  ...                       34642
# 2389  articles/t1065/raw_4081.txt  ...                       11979
# 2390  articles/t1065/raw_4081.txt  ...                       12544
# 2391  articles/t1065/raw_4081.txt  ...                       27912
# 2392  articles/t1065/raw_3722.txt  ...                       22153
# 2393  articles/t1065/raw_3722.txt  ...                       39273
#
#            claims.article.cleanFile claims.article.cleanSpan.start  \
# 0           articles/t1/clean_1.txt                            418
# 1           articles/t1/clean_1.txt                            829
# 2           articles/t1/clean_1.txt                           1004
# 3           articles/t1/clean_1.txt                           1442
# 4           articles/t1/clean_1.txt                           3900
# 5           articles/t1/clean_1.txt                           4124
# 6           articles/t1/clean_1.txt                           5608
# 7           articles/t1/clean_1.txt                           7084
# 8           articles/t1/clean_1.txt                           7476
# 9           articles/t1/clean_1.txt                           7599
# 10          articles/t1/clean_1.txt                           9761
# 11          articles/t1/clean_1.txt                           9922
# 12          articles/t1/clean_1.txt                          10017
# 13          articles/t1/clean_1.txt                          10575
# 14          articles/t1/clean_1.txt                          10714
# 15          articles/t1/clean_1.txt                          12724
# 16          articles/t1/clean_1.txt                          16664
# 17          articles/t1/clean_1.txt                          17623
# 18          articles/t1/clean_1.txt                          17887
# 19          articles/t1/clean_1.txt                          31698
# 20          articles/t1/clean_1.txt                          32354
# 21          articles/t1/clean_1.txt                          37325
# 22          articles/t1/clean_1.txt                          37791
# 23          articles/t1/clean_1.txt                          38898
# 24          articles/t1/clean_1.txt                          39621
# 25          articles/t1/clean_1.txt                          40016
# 26          articles/t1/clean_1.txt                          40248
# 27          articles/t1/clean_1.txt                          41967
# 28          articles/t1/clean_1.txt                          42558
# 29          articles/t1/clean_1.txt                          43272
# ...                             ...                            ...
# 2364  articles/t1065/clean_3651.txt                          14533
# 2365  articles/t1065/clean_3651.txt                          15287
# 2366  articles/t1065/clean_3651.txt                          15516
# 2367  articles/t1065/clean_3651.txt                          15796
# 2368  articles/t1065/clean_3651.txt                          16020
# 2369  articles/t1065/clean_3651.txt                          17881
# 2370  articles/t1065/clean_3720.txt                           6960
# 2371  articles/t1065/clean_3653.txt                           7535
# 2372  articles/t1065/clean_3653.txt                           7676
# 2373  articles/t1065/clean_3653.txt                          35444
# 2374  articles/t1065/clean_3653.txt                          35811
# 2375  articles/t1065/clean_3653.txt                          36195
# 2376  articles/t1065/clean_3653.txt                          37180
# 2377  articles/t1065/clean_3653.txt                          39647
# 2378  articles/t1065/clean_3653.txt                          39876
# 2379  articles/t1065/clean_3653.txt                          42175
# 2380  articles/t1065/clean_3653.txt                          45245
# 2381  articles/t1065/clean_3653.txt                          46751
# 2382  articles/t1065/clean_3652.txt                          37915
# 2383  articles/t1065/clean_3652.txt                          49303
# 2384  articles/t1065/clean_3652.txt                          50136
# 2385  articles/t1065/clean_3721.txt                           1850
# 2386  articles/t1065/clean_3721.txt                           9431
# 2387  articles/t1065/clean_4078.txt                           3508
# 2388  articles/t1065/clean_4080.txt                          30352
# 2389  articles/t1065/clean_4081.txt                           9636
# 2390  articles/t1065/clean_4081.txt                           9916
# 2391  articles/t1065/clean_4081.txt                          21369
# 2392  articles/t1065/clean_3722.txt                          17290
# 2393  articles/t1065/clean_3722.txt                          22389
#
#       claims.article.cleanSpan.end  claims.Compatible  \
# 0                              568                yes
# 1                              907                yes
# 2                             1082                yes
# 3                             1577                yes
# 4                             3948                yes
# 5                             4199                yes
# 6                             5792                yes
# 7                             7222                yes
# 8                             7571                yes
# 9                             7755                yes
# 10                            9852                yes
# 11                            9998                 no
# 12                           10080                yes
# 13                           10659                yes
# 14                           10782                yes
# 15                           12838                yes
# 16                           16757                yes
# 17                           17717                yes
# 18                           17941                yes
# 19                           31762                yes
# 20                           32466                yes
# 21                           37430                yes
# 22                           37895                yes
# 23                           38982                yes
# 24                           39675                yes
# 25                           40075                yes
# 26                           40307                yes
# 27                           42065                yes
# 28                           42663                yes
# 29                           43322                yes
# ...                            ...                ...
# 2364                         14560                yes
# 2365                         15311                yes
# 2366                         15620                yes
# 2367                         15866                yes
# 2368                         16062                yes
# 2369                         17958                 no
# 2370                          7026                yes
# 2371                          7645                yes
# 2372                          7714                yes
# 2373                         35488                yes
# 2374                         35886                yes
# 2375                         36259                yes
# 2376                         37255                yes
# 2377                         39718                yes
# 2378                         39961                yes
# 2379                         42216                yes
# 2380                         45308                yes
# 2381                         46789                yes
# 2382                         37975                yes
# 2383                         49375                yes
# 2384                         50241                yes
# 2385                          1985                yes
# 2386                          9478                yes
# 2387                          3633                yes
# 2388                         30388                yes
# 2389                          9730                yes
# 2390                          9994                yes
# 2391                         21429                yes
# 2392                         17370                yes
# 2393                         22429                 no
#
#                                 claims.claimTarget.text  \
# 0                       Exposure to violent video games
# 1                                   video game violence
# 2                              some violent video games
# 3                       exposure to violent video games
# 4                                   Violent video games
# 5                                      video game usage
# 6                                   violent video games
# 7                                 video game publishers
# 8                                   violent video games
# 9                       exposure to violent video games
# 10                           playing violent video game
# 11                                                  NaN
# 12                                        violent games
# 13       adolescents that don't play video games at all
# 14                                      video game play
# 15                   video game and other media effects
# 16                                  violent video games
# 17                 children playing violent video games
# 18                                  violent video games
# 19                                     Media influences
# 20                                  violent video games
# 21    Excessive exposure to violent video games and ...
# 22                          playing violent video games
# 23                                  violent video games
# 24                                          Video games
# 25                                        violent games
# 26                                        violent games
# 27                                the gaming experience
# 28                                                media
# 29                                          video games
# ...                                                 ...
# 2364                                          democracy
# 2365                                          democracy
# 2366                  the inclusive nature of democracy
# 2367                                          democracy
# 2368                                          democracy
# 2369                                                NaN
# 2370                                 democratic nations
# 2371                                        democracies
# 2372                                          Democracy
# 2373                                      majority rule
# 2374                                          democracy
# 2375                                          democracy
# 2376                                          democracy
# 2377                                A democratic system
# 2378                              The democratic system
# 2379                                     more democracy
# 2380                                        Democracies
# 2381                                 Democratic nations
# 2382                                        a democracy
# 2383     the concept of democracy as a constant process
# 2384                            democratic institutions
# 2385                                          democracy
# 2386                                          democracy
# 2387  the opportunity to decide what political matte...
# 2388                                          Democracy
# 2389                                        democracies
# 2390                                          democracy
# 2391                                          Democracy
# 2392                              democracy and freedom
# 2393                                                NaN
#
#      claims.claimTarget.span.start  claims.claimTarget.span.end  \
# 0                              0.0                         31.0
# 1                              0.0                         19.0
# 2                              0.0                         24.0
# 3                              0.0                         31.0
# 4                              0.0                         19.0
# 5                             37.0                         53.0
# 6                              0.0                         19.0
# 7                              0.0                         21.0
# 8                              0.0                         19.0
# 9                              0.0                         31.0
# 10                            44.0                         70.0
# 11                             NaN                          NaN
# 12                            27.0                         40.0
# 13                             0.0                         46.0
# 14                             0.0                         15.0
# 15                            74.0                        108.0
# 16                            69.0                         88.0
# 17                            32.0                         68.0
# 18                             0.0                         19.0
# 19                             0.0                         16.0
# 20                             0.0                         19.0
# 21                             0.0                         65.0
# 22                            36.0                         63.0
# 23                            32.0                         51.0
# 24                             0.0                         11.0
# 25                             0.0                         13.0
# 26                             0.0                         13.0
# 27                            32.0                         53.0
# 28                             0.0                          5.0
# 29                             0.0                         11.0
# ...                            ...                          ...
# 2364                           0.0                          9.0
# 2365                           0.0                          9.0
# 2366                           0.0                         33.0
# 2367                           0.0                          9.0
# 2368                           0.0                          9.0
# 2369                           NaN                          NaN
# 2370                           0.0                         18.0
# 2371                           0.0                         11.0
# 2372                           0.0                          9.0
# 2373                           0.0                         13.0
# 2374                           0.0                          9.0
# 2375                           0.0                          9.0
# 2376                           0.0                          9.0
# 2377                           0.0                         19.0
# 2378                           0.0                         21.0
# 2379                           0.0                         14.0
# 2380                           0.0                         11.0
# 2381                           0.0                         18.0
# 2382                           8.0                         19.0
# 2383                           0.0                         46.0
# 2384                           0.0                         23.0
# 2385                           0.0                          9.0
# 2386                           0.0                          9.0
# 2387                          17.0                        125.0
# 2388                           0.0                          9.0
# 2389                           0.0                         11.0
# 2390                           0.0                          9.0
# 2391                           0.0                          9.0
# 2392                           0.0                         21.0
# 2393                           NaN                          NaN
#
#       claims.claimSentiment  claims.targetsRelation
# 0                      -1.0                     1.0
# 1                       1.0                     1.0
# 2                       1.0                     1.0
# 3                      -1.0                     1.0
# 4                      -1.0                     1.0
# 5                       1.0                     1.0
# 6                      -1.0                     1.0
# 7                      -1.0                     1.0
# 8                      -1.0                     1.0
# 9                      -1.0                     1.0
# 10                      1.0                     1.0
# 11                      NaN                     NaN
# 12                      1.0                     1.0
# 13                     -1.0                    -1.0
# 14                      1.0                     1.0
# 15                      1.0                     1.0
# 16                     -1.0                     1.0
# 17                     -1.0                     1.0
# 18                     -1.0                     1.0
# 19                      1.0                     1.0
# 20                     -1.0                     1.0
# 21                     -1.0                     1.0
# 22                     -1.0                     1.0
# 23                      1.0                     1.0
# 24                      1.0                     1.0
# 25                      1.0                     1.0
# 26                      1.0                     1.0
# 27                      1.0                     1.0
# 28                      1.0                     1.0
# 29                      1.0                     1.0
# ...                     ...                     ...
# 2364                    1.0                     1.0
# 2365                   -1.0                     1.0
# 2366                    1.0                     1.0
# 2367                    1.0                     1.0
# 2368                    1.0                     1.0
# 2369                    NaN                     NaN
# 2370                    1.0                     1.0
# 2371                   -1.0                     1.0
# 2372                   -1.0                     1.0
# 2373                    1.0                     1.0
# 2374                    1.0                     1.0
# 2375                    1.0                     1.0
# 2376                   -1.0                     1.0
# 2377                    1.0                     1.0
# 2378                    1.0                     1.0
# 2379                    1.0                     1.0
# 2380                    1.0                     1.0
# 2381                    1.0                     1.0
# 2382                    1.0                     1.0
# 2383                   -1.0                     1.0
# 2384                   -1.0                     1.0
# 2385                    1.0                     1.0
# 2386                   -1.0                     1.0
# 2387                    1.0                     1.0
# 2388                   -1.0                     1.0
# 2389                   -1.0                     1.0
# 2390                   -1.0                     1.0
# 2391                   -1.0                     1.0
# 2392                    1.0                     1.0
# 2393                    NaN                     NaN
#
# [2394 rows x 21 columns]

# %%
# split train and test data and handle missing values
train,test = model.load_dataset(data)
print('Train Size',train.shape)
print('Test Size', test.shape)
# Out:
# Train Size (974, 19)
# Test Size (1286, 19)

# %% [markdown]
# # Select columns from  train data

# %%
claim_corrected_data_train = train.iloc[:,5]
claim_sentiment_data_train = train.iloc[:,17]

# %% [markdown]
# # Features calculation for the train data

# %%
# This step will take some time as feauture calculation of the claims will perfomed here 
X_train_data = model._instance_features(claim_corrected_data_train)

# %% [markdown]
# ## Following feaures are calculated from the claim senteces
# -                negative_score
# -                neutral_score
# -                positive_score
# -                compound_score
# -                num_of_positive_words
# -                num_of_negative_words
# -                num_of_neutral_words
# -                avg_tfidf_feature
# -                max_tfidf_feature

# %%
# claim sentences are converted into feauters
X_train_data
# Out:
#          0      1      2       3  4  5   6         7         8
# 0    0.141  0.643  0.217  0.2263  2  1  16  0.185419  0.510982
# 1    0.000  0.775  0.225  0.4404  1  0  10  0.283161  0.457109
# 2    0.000  1.000  0.000  0.0000  0  0  14  0.244215  0.367240
# 3    0.000  0.895  0.105  0.4019  1  0  23  0.187289  0.302452
# 4    0.000  1.000  0.000  0.0000  0  0  20  0.205836  0.332356
# 5    0.259  0.570  0.171 -0.1027  1  2   9  0.258621  0.393822
# 6    0.000  0.795  0.205  0.6597  2  0  21  0.157167  0.454011
# 7    0.000  1.000  0.000  0.0000  0  0   5  0.405347  0.632007
# 8    0.000  1.000  0.000  0.0000  0  0   8  0.335332  0.477992
# 9    0.000  0.709  0.291  0.5719  1  0   9  0.305195  0.391777
# 10   0.303  0.504  0.193 -0.0772  1  2   6  0.307308  0.466453
# 11   0.000  0.714  0.286  0.3818  2  0   9  0.261896  0.490557
# 12   0.000  0.847  0.153  0.2023  1  0  10  0.279030  0.440352
# 13   0.000  0.567  0.433  0.6249  3  0   8  0.284683  0.408424
# 14   0.346  0.247  0.407  0.1280  1  1   2  0.554716  0.505900
# 15   0.000  0.784  0.216  0.2960  1  0   8  0.305488  0.474552
# 16   0.000  0.784  0.216  0.3182  2  0  12  0.236210  0.396418
# 17   0.000  0.776  0.224  0.3818  1  0   9  0.249195  0.450215
# 18   0.125  0.667  0.208  0.2732  2  1  17  0.209722  0.322519
# 19   0.231  0.769  0.000 -0.2732  0  1   7  0.331191  0.479032
# 20   0.172  0.828  0.000 -0.3612  0  1  12  0.260062  0.367827
# 21   0.250  0.750  0.000 -0.4588  0  1   9  0.290200  0.443056
# 22   0.600  0.400  0.000 -0.4588  0  1   2  0.539510  0.693860
# 23   0.000  0.484  0.516  0.4939  1  0   3  0.482029  0.679319
# 24   0.000  0.658  0.342  0.3818  1  0   5  0.406688  0.440001
# 25   0.000  0.784  0.216  0.0258  1  0   4  0.444678  0.515681
# 26   0.211  0.789  0.000 -0.3400  1  1   9  0.225713  0.506788
# 27   0.164  0.669  0.167 -0.2263  4  2  21  0.129188  0.389853
# 28   0.286  0.714  0.000 -0.5574  0  1   9  0.274473  0.407312
# 29   0.000  1.000  0.000  0.0000  0  0  20  0.189168  0.317404
# ..     ...    ...    ...     ... .. ..  ..       ...       ...
# 944  0.000  0.458  0.542  0.7964  2  0   6  0.304679  0.448422
# 945  0.313  0.549  0.137 -0.4939  1  2  10  0.233855  0.389867
# 946  0.000  0.462  0.538  0.5423  1  0   3  0.493505  0.604108
# 947  0.552  0.448  0.000 -0.5719  0  1   3  0.459906  0.729016
# 948  0.331  0.669  0.000 -0.8360  0  2  16  0.196947  0.346735
# 949  0.112  0.426  0.463  0.7650  3  1   8  0.270603  0.398260
# 950  0.000  0.638  0.362  0.5267  1  0   6  0.304823  0.560482
# 951  0.330  0.670  0.000 -0.6637  0  1   9  0.307113  0.430075
# 952  0.263  0.737  0.000 -0.6908  0  2  16  0.210302  0.367854
# 953  0.000  1.000  0.000  0.0000  0  0   6  0.379558  0.595117
# 954  0.000  1.000  0.000  0.0000  0  0   7  0.352135  0.504677
# 955  0.460  0.540  0.000 -0.8598  0  2  10  0.266586  0.430180
# 956  0.255  0.745  0.000 -0.3400  0  1   7  0.336973  0.473297
# 957  0.224  0.597  0.179 -0.1531  1  1   8  0.301454  0.414986
# 958  0.000  0.734  0.266  0.4404  1  0   8  0.294467  0.449824
# 959  0.000  1.000  0.000  0.0000  0  0  11  0.257555  0.421371
# 960  0.000  0.488  0.512  0.6369  1  0   4  0.443567  0.545712
# 961  0.000  0.756  0.244  0.4404  1  0   9  0.293281  0.458805
# 962  0.000  1.000  0.000  0.0000  0  0   7  0.358369  0.495699
# 963  0.000  0.556  0.444  0.7506  2  0   8  0.236964  0.526992
# 964  0.000  1.000  0.000  0.0000  0  0  11  0.248251  0.440271
# 965  0.239  0.761  0.000 -0.5267  0  2  14  0.231767  0.380070
# 966  0.000  0.847  0.153  0.4404  1  0  16  0.173428  0.344242
# 967  0.000  1.000  0.000  0.0000  0  0   6  0.317441  0.582964
# 968  0.000  0.822  0.178  0.4404  2  0  18  0.196323  0.480140
# 969  0.403  0.597  0.000 -0.4019  0  1   4  0.401792  0.660080
# 970  0.000  0.844  0.156  0.3400  1  0  13  0.253149  0.366826
# 971  0.000  1.000  0.000  0.0000  0  0  14  0.240791  0.392561
# 972  0.342  0.658  0.000 -0.6369  0  2  10  0.253510  0.480118
# 973  0.000  0.556  0.444  0.7506  2  0   8  0.269106  0.463896
#
# [974 rows x 9 columns]

# %% [markdown]
# # select columns from test data

# %%
claim_corrected_data_test = test.iloc[:,5]
claim_target_data_test = test.iloc[:,14]
claim_sentiment_data_test = test.iloc[:,17]
topic_sentiment_data_test = test.iloc[:,2]
claim_target_data_relation = test.iloc[:,18]
topic_text = test.iloc[:,0]
stance_test = test.iloc[:,4]

# %%
# claim sentiment from train data
X_train_class_data =  claim_sentiment_data_train

# %% [markdown]
# # Training SVM model on features

# %%
from sklearn import svm
clf=svm.SVC(gamma='auto')
clf.fit(X_train_data,X_train_class_data)
Y_test_data = claim_corrected_data_test
Y_test_data_transfom = model._instance_features(claim_corrected_data_test)
actual = claim_sentiment_data_test
# predict claim sentiment on the test data
Y_test_class_data = clf.predict(Y_test_data_transfom)

# %% [markdown]
# # Confusion Matrix for predicted claim sentiment

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(actual, Y_test_class_data)
print(matrix)

# Calculating precision, recall, fmeasure, accuracy from confusion matrix
accuracy = (matrix[0][0]+matrix[1][1]) / (matrix[0][0]+matrix[1][1]+matrix[0][1]+matrix[1][0])
precision = matrix[1][1] / (matrix[0][1]+matrix[1][1])
recall    = matrix[0][0] / (matrix[0][0]+matrix[1][0])
f_measure = (2 * precision * recall ) / (precision + recall)
# Out:
# [[579 144]
#  [293 270]]

# %% [markdown]
# # Evaluation of model for claim prediction

# %%
print("  Accuracy    \t        precision  \t         Recall  \t    f_measure "   "\n", accuracy, precision, recall,f_measure )
# Out:
#   Accuracy    	        precision  	         Recall  	    f_measure
#  0.6601866251944012 0.6521739130434783 0.6639908256880734 0.6580293215138084

# %% [markdown]
# # Calculating stance

# %%
predicted_stance =  topic_sentiment_data_test * claim_target_data_relation * Y_test_class_data

# %%
predicted_stance
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# 5       1.0
# 6       1.0
# 7       1.0
# 8       1.0
# 9       1.0
# 10      1.0
# 12      1.0
# 13     -1.0
# 14     -1.0
# 15      1.0
# 16      1.0
# 17      1.0
# 18      1.0
# 19      1.0
# 20      1.0
# 21      1.0
# 22      1.0
# 23      1.0
# 24     -1.0
# 25      1.0
# 26      1.0
# 27     -1.0
# 28      1.0
# 29     -1.0
# 30      1.0
#        ...
# 1810   -1.0
# 1811   -1.0
# 1812    1.0
# 1813   -1.0
# 1814   -1.0
# 1815   -1.0
# 1816   -1.0
# 1817   -1.0
# 1818    1.0
# 1819    1.0
# 1820    1.0
# 1821   -1.0
# 1822   -1.0
# 1823    1.0
# 1824   -1.0
# 1825   -1.0
# 1826    1.0
# 1827    1.0
# 1828    1.0
# 1829    1.0
# 1830   -1.0
# 1831   -1.0
# 1832   -1.0
# 1833   -1.0
# 1834    1.0
# 1835   -1.0
# 1836   -1.0
# 1837   -1.0
# 1838   -1.0
# 1839   -1.0
# Length: 1286, dtype: float64

# %% [markdown]
# # Confusion Matrix for stance prediction

# %%
stance_filtered = stance_test.replace('PRO', 1)
stance_filtered = stance_filtered.replace('CON', -1)
# pro/ con to 1 / -1 
matrix = confusion_matrix(stance_filtered, predicted_stance)
print(matrix)
# Out:
# [[391 227]
#  [211 457]]

# %% [markdown]
# # Evaluation of model for stance prediction

# %%
accuracy_stance = (matrix[0][0]+matrix[1][1]) /(matrix[0][0]+matrix[1][1]+matrix[0][1]+matrix[1][0]) 
precision_stance = matrix[1][1] / (matrix[0][1]+matrix[1][1])
recall_stance    = matrix[0][0] / (matrix[0][0]+matrix[1][0])

f_measure_stance = (2 * precision * recall ) / (precision + recall)

predicted_stances = predicted_stance.replace(1, 'PRO')
predicted_stance = predicted_stances.replace(-1,'CON')
predicted_stance = (predicted_stance)

# %%
print("  Accuracy    \t        precision  \t         Recall "   "\n", accuracy_stance, precision_stance, recall_stance )
# Out:
#   Accuracy    	        precision  	         Recall
#  0.6594090202177294 0.6681286549707602 0.6495016611295681

# %% [markdown]
# # combining the result as a dataframe

# %%
DataFrameCombination = pd.concat([topic_text,claim_corrected_data_test,stance_test],axis =1)
DataFrameCombination['predicted.Stance'] = predicted_stance

# %% [markdown]
# # Printing the final result comparing actual stance with predicted stance ( calculated using formula)

# %%
DataFrameCombination
# Out:
#                                               topicText  \
# 0     This house believes that the sale of violent v...
# 1     This house believes that the sale of violent v...
# 2     This house believes that the sale of violent v...
# 3     This house believes that the sale of violent v...
# 4     This house believes that the sale of violent v...
# 5     This house believes that the sale of violent v...
# 6     This house believes that the sale of violent v...
# 7     This house believes that the sale of violent v...
# 8     This house believes that the sale of violent v...
# 9     This house believes that the sale of violent v...
# 10    This house believes that the sale of violent v...
# 12    This house believes that the sale of violent v...
# 13    This house believes that the sale of violent v...
# 14    This house believes that the sale of violent v...
# 15    This house believes that the sale of violent v...
# 16    This house believes that the sale of violent v...
# 17    This house believes that the sale of violent v...
# 18    This house believes that the sale of violent v...
# 19    This house believes that the sale of violent v...
# 20    This house believes that the sale of violent v...
# 21    This house believes that the sale of violent v...
# 22    This house believes that the sale of violent v...
# 23    This house believes that the sale of violent v...
# 24    This house believes that the sale of violent v...
# 25    This house believes that the sale of violent v...
# 26    This house believes that the sale of violent v...
# 27    This house believes that the sale of violent v...
# 28    This house believes that the sale of violent v...
# 29    This house believes that the sale of violent v...
# 30    This house believes that the sale of violent v...
# ...                                                 ...
# 1810  This house would only teach abstinence for sex...
# 1811  This house would only teach abstinence for sex...
# 1812  This house would only teach abstinence for sex...
# 1813  This house would only teach abstinence for sex...
# 1814  This house would only teach abstinence for sex...
# 1815  This house would only teach abstinence for sex...
# 1816  This house would only teach abstinence for sex...
# 1817  This house would only teach abstinence for sex...
# 1818  This house would only teach abstinence for sex...
# 1819  This house would only teach abstinence for sex...
# 1820  This house would only teach abstinence for sex...
# 1821  This house would only teach abstinence for sex...
# 1822  This house would only teach abstinence for sex...
# 1823  This house would only teach abstinence for sex...
# 1824  This house would only teach abstinence for sex...
# 1825  This house would only teach abstinence for sex...
# 1826  This house would only teach abstinence for sex...
# 1827  This house would only teach abstinence for sex...
# 1828  This house would only teach abstinence for sex...
# 1829  This house would only teach abstinence for sex...
# 1830  This house would only teach abstinence for sex...
# 1831  This house would only teach abstinence for sex...
# 1832  This house would only teach abstinence for sex...
# 1833  This house would only teach abstinence for sex...
# 1834  This house would only teach abstinence for sex...
# 1835  This house would only teach abstinence for sex...
# 1836  This house would only teach abstinence for sex...
# 1837  This house would only teach abstinence for sex...
# 1838  This house would only teach abstinence for sex...
# 1839  This house would only teach abstinence for sex...
#
#                               claims.claimCorrectedText claims.stance  \
# 0     Exposure to violent video games causes at leas...           PRO
# 1     video game violence is not related to serious ...           CON
# 2     some violent video games may actually have a p...           CON
# 3     exposure to violent video games causes both sh...           PRO
# 4     Violent video games increase the violent tende...           PRO
# 5     No conclusive link was found between video gam...           CON
# 6     violent video games are significantly associat...           PRO
# 7     video game publishers unethically train childr...           PRO
# 8     violent video games may increase mild forms of...           PRO
# 9     exposure to violent video games results in inc...           PRO
# 10    No long-term relationship was found between pl...           CON
# 12    No evidence has found that violent games are p...           CON
# 13    adolescents that don't play video games at all...           CON
# 14    video game play is part of an adolescent boy's...           CON
# 15    Biological theories of aggression and violence...           CON
# 16    Reinforcement of sexist stereotypes has been c...           PRO
# 17    A correlation was found between children playi...           PRO
# 18    violent video games can increase children's ag...           PRO
# 19    Media influences are too weak and distant to h...           CON
# 20    violent video games promote violent behavior, ...           PRO
# 21    Excessive exposure to violent video games and ...           PRO
# 22    Neurological link was found between playing vi...           PRO
# 23    There is no direct link between violent video ...           CON
# 24    Video games develop the individual's intelligence           CON
# 25    violent games help students deal with stress a...           CON
# 26    violent games affect students positively and n...           CON
# 27    many skills can be learned from the gaming exp...           CON
# 28    media cannot cause violence because humans hav...           CON
# 29    video games have many healthy and positive asp...           CON
# 30    Video games can be a safe outlet for aggressio...           CON
# ...                                                 ...           ...
# 1810            all abstinence programs are ineffective           CON
# 1811       abstinence only sex education is ineffective           CON
# 1812  Abstinence until marriage is the most effectiv...           PRO
# 1813  abstinence is the only guaranteed way of avoid...           PRO
# 1814  The lack of education on safe sex, whether it’...           CON
# 1815  comprehensive sex education would effectively ...           CON
# 1816  Comprehensive sex education encourages more an...           PRO
# 1817  Evidence does not support the use of abstinenc...           CON
# 1818  Providing safe-sex education promotes promiscuity           PRO
# 1819  Abstinence-only programs have no positive effects           CON
# 1820  sex education is necessary to prepare the youn...           CON
# 1821  Countries with conservative attitudes towards ...           CON
# 1822  broad sex education programs have global benefits           CON
# 1823  Sex education in school makes it easier for pa...           CON
# 1824  Adolescents want both to talk to their parents...           CON
# 1825  abstinence-only programs did not reduce the li...           CON
# 1826  the vast majority of Americans favor broader s...           CON
# 1827  open dialogue about physical intimacy and heal...           CON
# 1828     sexual behavior outside of marriage is immoral           PRO
# 1829  Abstinence is 100% effective in preventing pre...           PRO
# 1830  Abstinence-only education programs often provi...           CON
# 1831  Abstinence-only education will result in decre...           PRO
# 1832  Abstinence-only sex education programs show an...           CON
# 1833  Professional medical organizations oppose the ...           CON
# 1834  sexual abstinence confers numerous health bene...           PRO
# 1835  Sexual abstinence diminishes the risk of contr...           PRO
# 1836  sexual abstinence in teenagers decreases the r...           PRO
# 1837  excessive repression of the sexual instinct le...           CON
# 1838  Education programs which focus exclusively on ...           CON
# 1839  Sex-abstinence programs do not stop risky sexu...           CON
#
#      predicted.Stance
# 0                 PRO
# 1                 PRO
# 2                 PRO
# 3                 PRO
# 4                 PRO
# 5                 PRO
# 6                 PRO
# 7                 PRO
# 8                 PRO
# 9                 PRO
# 10                PRO
# 12                PRO
# 13                CON
# 14                CON
# 15                PRO
# 16                PRO
# 17                PRO
# 18                PRO
# 19                PRO
# 20                PRO
# 21                PRO
# 22                PRO
# 23                PRO
# 24                CON
# 25                PRO
# 26                PRO
# 27                CON
# 28                PRO
# 29                CON
# 30                PRO
# ...               ...
# 1810              CON
# 1811              CON
# 1812              PRO
# 1813              CON
# 1814              CON
# 1815              CON
# 1816              CON
# 1817              CON
# 1818              PRO
# 1819              PRO
# 1820              PRO
# 1821              CON
# 1822              CON
# 1823              PRO
# 1824              CON
# 1825              CON
# 1826              PRO
# 1827              PRO
# 1828              PRO
# 1829              PRO
# 1830              CON
# 1831              CON
# 1832              CON
# 1833              CON
# 1834              PRO
# 1835              CON
# 1836              CON
# 1837              CON
# 1838              CON
# 1839              CON
#
# [1286 rows x 4 columns]
